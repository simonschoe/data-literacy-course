# %% [markdown]
# ### Übungsaufgaben Kapitel 3 - Datenmanipulation und Datenanalyse

# %%
# Im Gegensatz zu `pandas` ist `openpyxl` noch nicht vorinstalliert (ggf. Neustart des Kernels erforderlich)
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\python\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\python\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# **Hinweis:** Wir benennen die Spaltennamen des *CEO dissmissal* Datensatzes beim Datenimport um, um uns nachfolgend die Verarbeitung zu erleichtern:
#
# ```python
# {'dismissal_dataset_id': 'id'
#  'coname': 'firm_name'
#  'gvkey': 'firm_id'
#  'year': 'year'
#  'co_per_rol': 'ceo_id'
#  'exec_fullname': 'ceo_name'
#  'Departure Code': 'depart_code'
#  'ceo_dismissal': 'ceo_dismi'
#  'Interim & Co-CEO': 'interim_or_co'
#  'tenure_no': 'tenure_no'
#  'max_tenure_ceodb': 'max_tenure'
#  'The fiscal year during which the CEO exited - for clarity': 'fy_gone'
#  'leftofc': 'date_gone'
#  'Still There': 'still_active'
#  'Notes and Thoughts': 'notes1'
#  'Notes 2': 'notes2'}
# ```

# %%
import pandas as pd

# %%
col_names = ['id', 'firm_name' , 'firm_id', 'year', 'ceo_id', 'ceo_name', 'depart_code', 'ceo_dismi', 'interim_or_co',
             'tenure_no', 'max_tenure', 'fy_gone', 'date_gone', 'still_active', 'notes1', 'notes2']

url = 'https://zenodo.org/record/4543893/files/CEO%20Dismissal%20Data%202021.02.03.xlsx?download=1'

df = pd.read_excel(url, 'Sheet1', engine='openpyxl', index_col=0, names=col_names)

df.head(n=5)
# Out:
#                      firm_name  firm_id  year  ceo_id
# id
# 1                     AAR CORP     1004  1995    5622  \
# 2                     AAR CORP     1004  2017    5623
# 3                     AAR CORP     1004  2018   51547
# 4   ADC TELECOMMUNICATIONS INC     1013  2000    2611
# 5   ADC TELECOMMUNICATIONS INC     1013  2003   23275
#
#                     ceo_name  depart_code  ceo_dismi interim_or_co  tenure_no
# id
# 1             Ira A. Eichner          5.0        0.0           NaN          1  \
# 2            David P. Storch          5.0        0.0           NaN          1
# 3   John McClain Holmes, III          NaN        NaN           NaN          1
# 4         William J. Cadogan          6.0        0.0           NaN          1
# 5         Richard R. Roscitt          6.0        0.0           NaN          1
#
#     max_tenure  fy_gone            date_gone still_active
# id
# 1            1   1996.0  1996-10-01 00:00:00          NaN  \
# 2            1   2018.0  2018-05-31 00:00:00          NaN
# 3            1      NaN                  NaN    17nov2020
# 4            1   2001.0  2001-02-15 00:00:00          NaN
# 5            1   2003.0  2003-08-13 00:00:00          NaN
#
#                                                notes1
# id
# 1   Mr. Ira A. Eichner served as CEO until October...  \
# 2   Agreed to stay as non-executive chairman post ...
# 3                                                 NaN
# 4   William Cadogan, the retiring CEO and chairman...
# 5   Richard R. "Rick" Roscitt has accepted a new p...
#
#                                                notes2
# id
# 1   https://www.comparably.com/companies/aar-corp/...
# 2   https://advance-lexis-com.umiss.idm.oclc.org/a...
# 3   https://www.aarcorp.com/about/corporate-officers/
# 4   https://www.bizjournals.com/twincities/stories...
# 5   https://www.businesswire.com/news/home/2003081...

# %% [markdown]
# ##### 3.4 Operationen auf Zeilen
#
# *Hinweis: Durch klick auf das kleine `+` in der oberen Toolbar oder durch selektieren einer Code Zelle und klicken der Tasten `a` (above) oder `b` (below) können neue Code Zellen eingefügt werden.*

# %% [markdown]
# 1. Selektiere die ersten 3 Beobachtungen des Datensatzes.

# %%
df.iloc[:3]  # oder: df.head(n=3)
# Out:
#    firm_name  firm_id  year  ceo_id                  ceo_name  depart_code
# id
# 1   AAR CORP     1004  1995    5622            Ira A. Eichner          5.0  \
# 2   AAR CORP     1004  2017    5623           David P. Storch          5.0
# 3   AAR CORP     1004  2018   51547  John McClain Holmes, III          NaN
#
#     ceo_dismi interim_or_co  tenure_no  max_tenure  fy_gone
# id
# 1         0.0           NaN          1           1   1996.0  \
# 2         0.0           NaN          1           1   2018.0
# 3         NaN           NaN          1           1      NaN
#
#               date_gone still_active
# id
# 1   1996-10-01 00:00:00          NaN  \
# 2   2018-05-31 00:00:00          NaN
# 3                   NaN    17nov2020
#
#                                                notes1
# id
# 1   Mr. Ira A. Eichner served as CEO until October...  \
# 2   Agreed to stay as non-executive chairman post ...
# 3                                                 NaN
#
#                                                notes2
# id
# 1   https://www.comparably.com/companies/aar-corp/...
# 2   https://advance-lexis-com.umiss.idm.oclc.org/a...
# 3   https://www.aarcorp.com/about/corporate-officers/

# %% [markdown]
# 2. Selektiere die letzten 100 Beobachtungen des Datensatzes.

# %%
df.iloc[-100:]  # oder: df.tail(n=100)
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 8939                HOMESTREET INC   187164  2010   54013  \
# 8940                HOMESTREET INC   187164  2017   54003
# 8941              AMC NETWORKS INC   187406  2017   46079
# 8942            ENPHASE ENERGY INC   187450  2017   64386
# 8943            ENPHASE ENERGY INC   187450  2019   64394
# ...                            ...      ...   ...     ...
# 9025  LYONDELLBASELL INDUSTRIES NV   294524  2017   46408
# 9026                  ALLEGION PLC   316056  2017   48314
# 9027                DORIAN LPG LTD   317264  2019   63143
# 9028            NVENT ELECTRIC PLC   326688  2019   62002
# 9029                    ARCOSA INC   328795  2019   61546
#
#                           ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 8939             Bruce W. Williams          3.0        1.0           NaN  \
# 8940                 Mark K. Mason          NaN        NaN           NaN
# 8941               Joshua W. Sapan          NaN        NaN           NaN
# 8942                  Paul B. Nahi          5.0        0.0           NaN
# 8943  Badrinarayanan Kothandaraman          NaN        NaN           NaN
# ...                            ...          ...        ...           ...
# 9025              Bhavesh V. Patel          NaN        NaN           NaN
# 9026             David D. Petratis          NaN        NaN           NaN
# 9027          John C. Hadjipateras          NaN        NaN           NaN
# 9028               Beth A. Wozniak          NaN        NaN           NaN
# 9029              Antonio Carrillo          NaN        NaN           NaN
#
#       tenure_no  max_tenure  fy_gone            date_gone still_active
# id
# 8939          1           1   2010.0  2010-01-20 00:00:00          NaN  \
# 8940          1           1      NaN                  NaN          Yes
# 8941          1           1      NaN                  NaN          Yes
# 8942          1           1   2017.0  2017-08-08 00:00:00          NaN
# 8943          1           1      NaN                  NaN     probably
# ...         ...         ...      ...                  ...          ...
# 9025          1           1      NaN                  NaN    03feb2021
# 9026          1           1      NaN                  NaN    03feb2021
# 9027          1           1      NaN                  NaN    03feb2021
# 9028          1           1      NaN                  NaN    03feb2021
# 9029          1           1      NaN                  NaN    03feb2021
#
#                                                  notes1
# id
# 8939  Bank was going through financial and perfomanc...  \
# 8940                                                NaN
# 8941                                                NaN
# 8942  Petaluma-based Enphase Energy, Inc. (NASDAQ:EN...
# 8943                                                NaN
# ...                                                 ...
# 9025                                                NaN
# 9026                                                NaN
# 9027                                                NaN
# 9028                                                NaN
# 9029                                                NaN
#
#                                                  notes2
# id
# 8939  https://www.bizjournals.com/seattle/stories/20...
# 8940                                                NaN
# 8941                                                NaN
# 8942  https://www.northbaybusinessjournal.com/articl...
# 8943                                                NaN
# ...                                                 ...
# 9025                                                NaN
# 9026                                                NaN
# 9027  https://dorianlpg.com/about/management/default...
# 9028  https://www.nvent.com/en-us/about-nvent/execut...
# 9029  https://craft.co/arcosa/executives#:~:text=Arc...
#
# [100 rows x 15 columns]

# %% [markdown]
# 3. Selektiere alle Beobachtungen aus dem Jahr 2000 und früher (Spalte `year`).

# %%
df[df['year'] <= 2000]
# Out:
#                        firm_name  firm_id  year  ceo_id            ceo_name
# id
# 1                       AAR CORP     1004  1995    5622      Ira A. Eichner  \
# 4     ADC TELECOMMUNICATIONS INC     1013  2000    2611  William J. Cadogan
# 7             ALPHARMA INC -CL A     1034  1993    5628    Jeffrey E. Smith
# 8             ALPHARMA INC -CL A     1034  1998    5627    Einar W. Sissner
# 9             ALPHARMA INC -CL A     1034  1999   16765      Gert W. Munthe
# ...                          ...      ...   ...     ...                 ...
# 7993  HANCOCK JOHN FINL SVCS INC   128659  2000   22532    Stephen L. Brown
# 8005                    PALM INC   132502  1999   20172    Eric A. Benhamou
# 8006                    PALM INC   132502  2000   20173   Carl J. Yankowski
# 8013           GRANT PRIDECO INC   133170  2000   21948       John C. Coble
# 8246       VIASYS HEALTHCARE INC   145854  2000   23147     William B. Ross
#
#       depart_code  ceo_dismi interim_or_co  tenure_no  max_tenure  fy_gone
# id
# 1             5.0        0.0           NaN          1           1   1996.0  \
# 4             6.0        0.0           NaN          1           1   2001.0
# 7             5.0        0.0           NaN          1           1   1994.0
# 8             5.0        0.0           NaN          1           1   1999.0
# 9             5.0        0.0           NaN          1           1   1999.0
# ...           ...        ...           ...        ...         ...      ...
# 7993          5.0        0.0           NaN          1           1   2000.0
# 8005          7.0        0.0           NaN          1           2      NaN
# 8006          3.0        1.0           NaN          1           1   2001.0
# 8013          3.0        1.0           NaN          1           1   2001.0
# 8246          7.0        0.0       Interim          1           1   2001.0
#
#                 date_gone still_active
# id
# 1     1996-10-01 00:00:00          NaN  \
# 4     2001-02-15 00:00:00          NaN
# 7     1994-06-01 00:00:00          NaN
# 8     1999-06-01 00:00:00          NaN
# 9     1999-12-31 00:00:00          NaN
# ...                   ...          ...
# 7993  2000-06-01 00:00:00          NaN
# 8005                  NaN          NaN
# 8006  2001-11-08 00:00:00          NaN
# 8013  2001-02-01 00:00:00          NaN
# 8246  2001-04-01 00:00:00          NaN
#
#                                                  notes1
# id
# 1     Mr. Ira A. Eichner served as CEO until October...  \
# 4     William Cadogan, the retiring CEO and chairman...
# 7     From 1985 to 2002, Jeffrey E. Smith served in ...
# 8     Alpharma Inc. announced that Einar W. Sissener...
# 9     Munthe became CEO in June 1999, preparing to t...
# ...                                                 ...
# 7993  During the transition to taking John Hancock p...
# 8005  It does not look like he was CEO of Palm. Inst...
# 8006  Mr. Yankowski resigned as the CEO of Palm, Inc...
# 8013  Although there was not a lot of information he...
# 8246  Willliam Ross served as interim CEO and later ...
#
#                                                  notes2
# id
# 1     https://www.comparably.com/companies/aar-corp/...
# 4     https://www.bizjournals.com/twincities/stories...
# 7     https://www.biospace.com/article/releases/pdi-...
# 8     https://www.biospace.com/article/releases/-b-e...
# 9     https://www.referenceforbusiness.com/history2/...
# ...                                                 ...
# 7993  D'alessandro takes john hancock post of chief ...
# 8005  https://www.industryweek.com/leadership/compan...
# 8006  Link 1: https://www.cnet.com/news/yankowski-ou...
# 8013  https://www.drillingcontractor.org/dcpi/2001/d...
# 8246  https://www.twelfthmantec.com/management/\n ht...
#
# [2460 rows x 15 columns]

# %% [markdown]
# 4. Selektiere alle Beobachtungen aus dem Jahr 2000 und früher oder 2010 und später (Spalte `year`).

# %%
df[(df['year'] <= 2000) | (df['year'] >= 2010)]
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 1                         AAR CORP     1004  1995    5622  \
# 2                         AAR CORP     1004  2017    5623
# 3                         AAR CORP     1004  2018   51547
# 4       ADC TELECOMMUNICATIONS INC     1013  2000    2611
# 6       ADC TELECOMMUNICATIONS INC     1013  2010    8741
# ...                            ...      ...   ...     ...
# 9025  LYONDELLBASELL INDUSTRIES NV   294524  2017   46408
# 9026                  ALLEGION PLC   316056  2017   48314
# 9027                DORIAN LPG LTD   317264  2019   63143
# 9028            NVENT ELECTRIC PLC   326688  2019   62002
# 9029                    ARCOSA INC   328795  2019   61546
#
#                       ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 1               Ira A. Eichner          5.0        0.0           NaN  \
# 2              David P. Storch          5.0        0.0           NaN
# 3     John McClain Holmes, III          NaN        NaN           NaN
# 4           William J. Cadogan          6.0        0.0           NaN
# 6              Robert E. Switz          7.0        0.0           NaN
# ...                        ...          ...        ...           ...
# 9025          Bhavesh V. Patel          NaN        NaN           NaN
# 9026         David D. Petratis          NaN        NaN           NaN
# 9027      John C. Hadjipateras          NaN        NaN           NaN
# 9028           Beth A. Wozniak          NaN        NaN           NaN
# 9029          Antonio Carrillo          NaN        NaN           NaN
#
#       tenure_no  max_tenure  fy_gone            date_gone still_active
# id
# 1             1           1   1996.0  1996-10-01 00:00:00          NaN  \
# 2             1           1   2018.0  2018-05-31 00:00:00          NaN
# 3             1           1      NaN                  NaN    17nov2020
# 4             1           1   2001.0  2001-02-15 00:00:00          NaN
# 6             1           1   2011.0  2010-12-01 00:00:00          NaN
# ...         ...         ...      ...                  ...          ...
# 9025          1           1      NaN                  NaN    03feb2021
# 9026          1           1      NaN                  NaN    03feb2021
# 9027          1           1      NaN                  NaN    03feb2021
# 9028          1           1      NaN                  NaN    03feb2021
# 9029          1           1      NaN                  NaN    03feb2021
#
#                                                  notes1
# id
# 1     Mr. Ira A. Eichner served as CEO until October...  \
# 2     Agreed to stay as non-executive chairman post ...
# 3                                                   NaN
# 4     William Cadogan, the retiring CEO and chairman...
# 6     Robert E. Switz was the chairman, president an...
# ...                                                 ...
# 9025                                                NaN
# 9026                                                NaN
# 9027                                                NaN
# 9028                                                NaN
# 9029                                                NaN
#
#                                                  notes2
# id
# 1     https://www.comparably.com/companies/aar-corp/...
# 2     https://advance-lexis-com.umiss.idm.oclc.org/a...
# 3     https://www.aarcorp.com/about/corporate-officers/
# 4     https://www.bizjournals.com/twincities/stories...
# 6     https://www.micron.com/about/our-company/leade...
# ...                                                 ...
# 9025                                                NaN
# 9026                                                NaN
# 9027  https://dorianlpg.com/about/management/default...
# 9028  https://www.nvent.com/en-us/about-nvent/execut...
# 9029  https://craft.co/arcosa/executives#:~:text=Arc...
#
# [6788 rows x 15 columns]

# %% [markdown]
# 5. Selektiere alle CEOs, denen in der zweiten Amtszeit (`tenure_no == 2`) gekündigt wurde (`ceo_dismi == 1`).

# %%
df[(df['tenure_no'] == 2) & (df['ceo_dismi'] == 1)]
# Out:
#                            firm_name  firm_id  year  ceo_id
# id
# 215             SCHOOL SPECIALTY INC     1634  2007   20390  \
# 931             BIGLARI HOLDINGS INC     3424  2008   13505
# 1129           DOWNEY FINANCIAL CORP     4065  2007   16393
# 1857             INTL RECTIFIER CORP     6109  2008    6126
# 1947             SEARS HOLDINGS CORP     6307  2007   30369
# 2441                     AVATEX CORP     7745  2001    1573
# 2445           TENET HEALTHCARE CORP     7750  2017   10390
# 2810                    AGILYSYS INC     8599  2008    6481
# 2811                    AGILYSYS INC     8599  2010   27948
# 3179                         KEYCORP     9783  2000    2048
# 3279    STEWART INFORMATION SERVICES    10086  2011   22976
# 3733        WASTE MANAGEMENT INC-OLD    11306  1997    2357
# 4295             INDYMAC BANCORP INC    13166  2007   21725
# 4771                  HOUSE2HOME INC    15360  2000    4533
# 4836                    LECHTERS INC    16454  2000   10578
# 5355                     BIOLASE INC    23291  2007   36160
# 6235    PAPA JOHNS INTERNATIONAL INC    28397  2017   17117
# 556717             RENT-A-CENTER INC    31460  2017   36115
# 6837                      MEDNAX INC    61325  2017   15136
# 7029         LUCENT TECHNOLOGIES INC    62599  2001   11600
# 7281           MONSTER WORLDWIDE INC    64156  2006   22327
# 7350          MEADE INSTRUMENTS CORP    64595  2012   20297
# 8031                  CONVERSANT INC   133547  2009   33161
# 8142                    INSEEGO CORP   141178  2014   31116
# 8596      CHIPOTLE MEXICAN GRILL INC   165914  2017   36060
#
#                      ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 215        Michael J. LaVelle          3.0        1.0           NaN  \
# 931            Alan B. Gilman          3.0        1.0       Interim
# 1129      Daniel D. Rosenthal          3.0        1.0           NaN
# 1857    Alexander Lidow Ph.D.          4.0        1.0           NaN
# 1947          Aylwin B. Lewis          3.0        1.0           NaN
# 2441          Abbey J. Butler          3.0        1.0        CO-CEO
# 2445            Trevor Fetter          3.0        1.0           NaN
# 2810             Arthur Rhein          3.0        1.0           NaN
# 2811          Martin F. Ellis          3.0        1.0           NaN
# 3179      Robert W. Gillespie          3.0        1.0           NaN
# 3279       Stewart Morris Jr.          3.0        1.0        CO-CEO
# 3733         Dean L. Buntrock          3.0        1.0       Interim
# 4295         Michael W. Perry          3.0        1.0           NaN
# 4771        Herbert J. Zarkin          3.0        1.0           NaN
# 4836             Donald Jonas          3.0        1.0           NaN
# 5355         Jeffrey W. Jones          3.0        1.0           NaN
# 6235        John H. Schnatter          4.0        1.0           NaN
# 556717         Mark E. Speese          3.0        1.0           NaN
# 6837           Roger J. Medel          3.0        1.0           NaN
# 7029     Henry Brewer Schacht          3.0        1.0           NaN
# 7281       Andrew J. McKelvey          4.0        1.0           NaN
# 7350        Steven G. Murdock          3.0        1.0           NaN
# 8031        Thomas A. Vadnais          3.0        1.0           NaN
# 8142        Peter V. Leparulo          3.0        1.0           NaN
# 8596           M. Steven Ells          3.0        1.0           NaN
#
#         tenure_no  max_tenure  fy_gone            date_gone still_active
# id
# 215             2           2   2013.0  2013-08-02 00:00:00          NaN  \
# 931             2           2   2008.0  2008-03-01 00:00:00          NaN
# 1129            2           2   2008.0  2008-07-01 00:00:00          NaN
# 1857            2           2   2008.0  2007-10-01 00:00:00          NaN
# 1947            2           2   2008.0  2008-02-01 00:00:00          NaN
# 2441            2           2   2002.0  2002-12-11 00:00:00          NaN
# 2445            2           2   2017.0  2017-10-23 00:00:00          NaN
# 2810            2           2   2008.0  2008-10-20 00:00:00          NaN
# 2811            2           2   2011.0  2011-06-01 00:00:00          NaN
# 3179            2           2   2001.0  2001-02-01 00:00:00          NaN
# 3279            2           2   2011.0  2011-11-01 00:00:00          NaN
# 3733            2           2   1997.0  1997-07-15 00:00:00          NaN
# 4295            2           1   2008.0  2008-07-11 00:00:00          NaN
# 4771            2           2   2000.0  2001-01-01 00:00:00          NaN
# 4836            2           2   2000.0  2000-11-16 00:00:00          NaN
# 5355            2           2   2007.0  2007-11-05 00:00:00          NaN
# 6235            2           2   2017.0  2017-12-01 00:00:00          NaN
# 556717          2           2   2018.0  2018-01-01 00:00:00          NaN
# 6837            2           2   2020.0  2020-07-12 00:00:00          NaN
# 7029            2           2   2002.0  2002-06-01 00:00:00          NaN
# 7281            2           2   2006.0  2006-10-06 00:00:00          NaN
# 7350            2           2   2019.0  2019-11-01 00:00:00          NaN
# 8031            2           2   2010.0  2010-04-09 00:00:00          NaN
# 8142            2           2   2014.0  2014-06-13 00:00:00          NaN
# 8596            2           2   2017.0  2017-11-29 00:00:00          NaN
#
#                                                    notes1
# id
# 215     "GREENVILLE, Wis., July 22, 2013 – School Spec...  \
# 931     In the first quarter of 2008, Steak n Shake sw...
# 1129    Mr. McAlister noted that Daniel D. Rosenthal, ...
# 1857    Alex Lidow resigned from the position of CEO i...
# 1947    Sears Holdings Corp. abruptly announced the de...
# 2441       Co ceo arranagement and the firm went bankrupt
# 2445    CEO Trevor Fetter has resigned amid the compan...
# 2810    Mr. Rhein resigned as Chairman, C.E.O., and Pr...
# 2811    Agilysys said that then-Chief Executive Office...
# 3179    Retired three months before his contract ended...
# 3279    Activist shareholder pushed the removal of boa...
# 3733    Bloomberg talks about how he was nudged off th...
# 4295    The company went bust when the mortgage sub we...
# 4771    Company went backrupt again in 2001 and was li...
# 4836    In late 2000, the company announced that its c...
# 5355    Multiple sites state that the company was unde...
# 6235    Papa John's founder John Schnatter has agreed ...
# 556717  He started this stint as interim but stayed on...
# 6837    These announcements are pursuant to an agreeme...
# 7029    Schacht steps down after an inability to reviv...
# 7281    McKelvey left the company amid questions about...
# 7350    Company reinstated old CEO and the company end...
# 8031    Tom A. Vadnais resigned and retired from his o...
# 8142    Company had suffered a long string of disappoi...
# 8596    Steve Ells has stepped down as CEO of Chipotle...
#
#                                                    notes2
# id
# 215     https://www.sec.gov/Archives/edgar/data/105545...
# 931     https://www.siliconinvestor.com/readmsg.aspx?m...
# 1129    Dobbs, K. (2008, Aug 01). Did an exit add opti...
# 1857    https://www.eetimes.com/document.asp?doc_id=12...
# 1947    http://www.nbcnews.com/id/22879044/ns/business...
# 2441    https://www.wsj.com/articles/SB875574127133314...
# 2445    https://www.modernhealthcare.com/article/20171...
# 2810    https://www.crn.com/news/channel-programs/2113...
# 2811    https://www.cleveland.com/business/2011/06/agi...
# 3179    https://www.nytimes.com/2001/01/19/business/co...
# 3279    https://www.prnewswire.com/news-releases/stewa...
# 3733    https://www.wsj.com/articles/SB951274040955526...
# 4295    https://www.reuters.com/article/indymac-execut...
# 4771    https://www.sandiegouniontribune.com/sdut-hous...
# 4836    http://www.fundinguniverse.com/company-histori...
# 5355    https://www.ocregister.com/2007/11/06/biolase-...
# 6235    https://www.nbcnews.com/business/business-news...
# 556717  https://www.businesswire.com/news/home/2017041...
# 6837    https://exechange.com/20008/mednax-ceo-roger-m...
# 7029    https://www.chicagotribune.com/news/ct-xpm-200...
# 7281    http://www.tributes.com/obituary/print/8462905...
# 7350      https://en.wikipedia.org/wiki/Meade_Instruments
# 8031    https://www.conversantmedia.com/about-us/press...
# 8142    https://www.sdbj.com/news/2014/jun/15/novatel-...
# 8596    https://www.restaurantbusinessonline.com/chipo...

# %% [markdown]
# 6. Selektiere alle Beobachtungen, zu denen es denen es keine Notizen gibt (d.h. `notes1` enthält keinen Eintrag).

# %%
df.dropna(axis=0, how='any', subset=['notes1'])  # oder: df[df['notes1'].notna()], df[~df['notes1'].isna()]
# Out:
#                          firm_name  firm_id  year  ceo_id            ceo_name
# id
# 1                         AAR CORP     1004  1995    5622      Ira A. Eichner  \
# 2                         AAR CORP     1004  2017    5623     David P. Storch
# 4       ADC TELECOMMUNICATIONS INC     1013  2000    2611  William J. Cadogan
# 5       ADC TELECOMMUNICATIONS INC     1013  2003   23275  Richard R. Roscitt
# 6       ADC TELECOMMUNICATIONS INC     1013  2010    8741     Robert E. Switz
# ...                            ...      ...   ...     ...                 ...
# 9019    GLOBE SPECIALTY METALS INC   274165  2008   46094     Alan Kestenbaum
# 9020    GLOBE SPECIALTY METALS INC   274165  2015   46092  Jeffrey K. Bradley
# 9021               FUTUREFUEL CORP   287462  2013   48303       Lee E. Mikles
# 9023  LYONDELLBASELL INDUSTRIES NV   294524  2009   46402       Volker Trautz
# 9024  LYONDELLBASELL INDUSTRIES NV   294524  2014   46407   James L. Gallogly
#
#       depart_code  ceo_dismi interim_or_co  tenure_no  max_tenure  fy_gone
# id
# 1             5.0        0.0           NaN          1           1   1996.0  \
# 2             5.0        0.0           NaN          1           1   2018.0
# 4             6.0        0.0           NaN          1           1   2001.0
# 5             6.0        0.0           NaN          1           1   2003.0
# 6             7.0        0.0           NaN          1           1   2011.0
# ...           ...        ...           ...        ...         ...      ...
# 9019          5.0        0.0           NaN          1           1   2008.0
# 9020          7.0        0.0           NaN          1           1   2016.0
# 9021          5.0        0.0           NaN          1           1   2013.0
# 9023          7.0        0.0           NaN          1           1   2009.0
# 9024          5.0        0.0           NaN          1           1   2015.0
#
#                 date_gone still_active
# id
# 1     1996-10-01 00:00:00          NaN  \
# 2     2018-05-31 00:00:00          NaN
# 4     2001-02-15 00:00:00          NaN
# 5     2003-08-13 00:00:00          NaN
# 6     2010-12-01 00:00:00          NaN
# ...                   ...          ...
# 9019  2008-06-02 00:00:00          NaN
# 9020  2015-10-22 00:00:00          NaN
# 9021  2013-01-01 00:00:00          NaN
# 9023  2009-05-01 00:00:00          NaN
# 9024  2015-01-12 00:00:00          NaN
#
#                                                  notes1
# id
# 1     Mr. Ira A. Eichner served as CEO until October...  \
# 2     Agreed to stay as non-executive chairman post ...
# 4     William Cadogan, the retiring CEO and chairman...
# 5     Richard R. "Rick" Roscitt has accepted a new p...
# 6     Robert E. Switz was the chairman, president an...
# ...                                                 ...
# 9019  NEW YORK, June, 2 2008 - Globe Specialty Metal...
# 9020  MIAMI and MADRID - July 13, 2015 (GLOBE NEWSWI...
# 9021  Lee E. Mikles has submitted his resignation, e...
# 9023  Mr. Volker Trautz has announced his retirement...
# 9024  James Gallogly, announced his plans to retire ...
#
#                                                  notes2
# id
# 1     https://www.comparably.com/companies/aar-corp/...
# 2     https://advance-lexis-com.umiss.idm.oclc.org/a...
# 4     https://www.bizjournals.com/twincities/stories...
# 5     https://www.businesswire.com/news/home/2003081...
# 6     https://www.micron.com/about/our-company/leade...
# ...                                                 ...
# 9019  (June 2, 2008 Monday). Globe SpecialtyMetal Ap...
# 9020  https://investor.ferroglobe.com/news-releases/...
# 9021  https://www.stltoday.com/business/local/novell...
# 9023  https://ftalphaville.ft.com/2009/01/06/50826/l...
# 9024  https://www.houstonchronicle.com/business/ener...
#
# [7743 rows x 15 columns]

# %% [markdown]
# 7. Selektiere alle Beobachtungen, zu denen es denen es Notizen gibt (d.h. `notes1` enthält einen Eintrag).

# %%
df[df['notes1'].isna()]  # oder: df[~df['notes1'].notna()]
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 3                         AAR CORP     1004  2018   51547  \
# 16     AMERICAN AIRLINES GROUP INC     1045  2019   49256
# 20                    AEROFLEX INC     1056  2008   19963
# 23                        AVX CORP     1072  2018   53405
# 30                     AARON'S INC     1076  2019   50434
# ...                            ...      ...   ...     ...
# 9025  LYONDELLBASELL INDUSTRIES NV   294524  2017   46408
# 9026                  ALLEGION PLC   316056  2017   48314
# 9027                DORIAN LPG LTD   317264  2019   63143
# 9028            NVENT ELECTRIC PLC   326688  2019   62002
# 9029                    ARCOSA INC   328795  2019   61546
#
#                       ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 3     John McClain Holmes, III          NaN        NaN           NaN  \
# 16      William Douglas Parker          NaN        NaN           NaN
# 20               Leonard Borow          NaN        NaN           NaN
# 23                 John Sarvis          NaN        NaN           NaN
# 30        John W. Robinson III          NaN        NaN           NaN
# ...                        ...          ...        ...           ...
# 9025          Bhavesh V. Patel          NaN        NaN           NaN
# 9026         David D. Petratis          NaN        NaN           NaN
# 9027      John C. Hadjipateras          NaN        NaN           NaN
# 9028           Beth A. Wozniak          NaN        NaN           NaN
# 9029          Antonio Carrillo          NaN        NaN           NaN
#
#       tenure_no  max_tenure  fy_gone date_gone still_active notes1
# id
# 3             1           1      NaN       NaN    17nov2020    NaN  \
# 16            1           1      NaN       NaN    16nov2020    NaN
# 20            1           1      NaN       NaN    16nov2020    NaN
# 23            1           1      NaN       NaN    16nov2020    NaN
# 30            1           1      NaN       NaN    16nov2020    NaN
# ...         ...         ...      ...       ...          ...    ...
# 9025          1           1      NaN       NaN    03feb2021    NaN
# 9026          1           1      NaN       NaN    03feb2021    NaN
# 9027          1           1      NaN       NaN    03feb2021    NaN
# 9028          1           1      NaN       NaN    03feb2021    NaN
# 9029          1           1      NaN       NaN    03feb2021    NaN
#
#                                                  notes2
# id
# 3     https://www.aarcorp.com/about/corporate-officers/
# 16    https://www.aa.com/i18n/customer-service/about...
# 20     https://www.bloomberg.com/profile/person/1445657
# 23    https://www.marketscreener.com/business-leader...
# 30    https://investor.aarons.com/management/john-ro...
# ...                                                 ...
# 9025                                                NaN
# 9026                                                NaN
# 9027  https://dorianlpg.com/about/management/default...
# 9028  https://www.nvent.com/en-us/about-nvent/execut...
# 9029  https://craft.co/arcosa/executives#:~:text=Arc...
#
# [1647 rows x 15 columns]

# %% [markdown]
# 8. Sortiere den Datensatz nach dem `year` in absteigender Reihenfolge und speichere das Resultat in der Variable `df_sorted`.

# %%
df_sorted = df.sort_values(by='year', ascending=False)
df_sorted
# Out:
#                      firm_name  firm_id  year  ceo_id            ceo_name
# id
# 1996  KELLY SERVICES INC -CL A     6379  2109   34754    George S. Corona  \
# 8193             ACCENTURE PLC   143357  2020   44905     Pierre Nanterme
# 9029                ARCOSA INC   328795  2019   61546    Antonio Carrillo
# 6119                INTUIT INC    27928  2019   35937   Sasan K. Goodarzi
# 6069              NAUTILUS INC    27760  2019   63827      James Barr, IV
# ...                        ...      ...   ...     ...                 ...
# 5458           PANERA BREAD CO    24113  1992    8073       Louis I. Kane
# 335         BALDOR ELECTRIC CO     1981  1992    5686   R. S. Boreham Jr.
# 2542      NORTEL NETWORKS CORP     7980  1992    1648   Paul George Stern
# 1698             HONEYWELL INC     5693  1992    1162     James J. Renier
# 1296              FEDDERS CORP     4595  1987    8921  Salvatore Giordano
#
#       depart_code  ceo_dismi interim_or_co  tenure_no  max_tenure  fy_gone
# id
# 1996          5.0        0.0           NaN          1           1   2019.0  \
# 8193          2.0        0.0           NaN          1           1   2019.0
# 9029          NaN        NaN           NaN          1           1      NaN
# 6119          NaN        NaN           NaN          1           1      NaN
# 6069          NaN        NaN           NaN          1           1      NaN
# ...           ...        ...           ...        ...         ...      ...
# 5458          5.0        0.0           NaN          1           1   1994.0
# 335           5.0        0.0           NaN          1           2   1993.0
# 2542          3.0        1.0           NaN          1           1   1993.0
# 1698          3.0        1.0           NaN          1           1   1993.0
# 1296          5.0        0.0           NaN          1           2   1988.0
#
#                 date_gone still_active
# id
# 1996  2019-09-30 00:00:00          NaN  \
# 8193  2019-01-10 00:00:00          NaN
# 9029                  NaN    03feb2021
# 6119                  NaN     probably
# 6069                  NaN     probably
# ...                   ...          ...
# 5458  1994-05-25 00:00:00          NaN
# 335   1993-01-03 00:00:00          NaN
# 2542  1993-02-28 00:00:00          NaN
# 1698  1993-04-20 00:00:00          NaN
# 1296  1988-01-01 00:00:00          NaN
#
#                                                  notes1
# id
# 1996  Executive gave one month notice although the c...  \
# 8193  Accenture PLC announced in a January 11th, 201...
# 9029                                                NaN
# 6119                                                NaN
# 6069                                                NaN
# ...                                                 ...
# 5458  LOUIS I. KANE, Director since 1981, co-founder...
# 335   Roland S. Boreham, Jr., was Baldor’s CEO from ...
# 2542  With profits and the share price dropping, Pau...
# 1698  Renier resigned as chairman and CEO in 1993, s...
# 1296  Salvatore Giordano passed away 02/22/2003. Thi...
#
#                                                  notes2
# id
# 1996  https://exechange.com/13794/kelly-services-ceo...
# 8193  https://newsroom.accenture.com/news/accenture-...
# 9029  https://craft.co/arcosa/executives#:~:text=Arc...
# 6119                                                NaN
# 6069                                                NaN
# ...                                                 ...
# 5458  https://sec.report/Document/0001029869-98-0007...
# 335   http://www.annualreports.com/HostedData/Annual...
# 2542  https://www.theglobeandmail.com/report-on-busi...
# 1698  http://www.fundinguniverse.com/company-histori...
# 1296  https://www.newjerseyhills.com/salvatore-giord...
#
# [9390 rows x 15 columns]

# %% [markdown]
# 9. Sortiere den Datensatz nach dem `year` in absteigender Reihenfolge und überschreibe den original Datensatz unter Verwendung des `inplace` Arguments.

# %%
df.sort_values(by='year', ascending=False, inplace=True)
df
# Out:
#                      firm_name  firm_id  year  ceo_id            ceo_name
# id
# 1996  KELLY SERVICES INC -CL A     6379  2109   34754    George S. Corona  \
# 8193             ACCENTURE PLC   143357  2020   44905     Pierre Nanterme
# 9029                ARCOSA INC   328795  2019   61546    Antonio Carrillo
# 6119                INTUIT INC    27928  2019   35937   Sasan K. Goodarzi
# 6069              NAUTILUS INC    27760  2019   63827      James Barr, IV
# ...                        ...      ...   ...     ...                 ...
# 5458           PANERA BREAD CO    24113  1992    8073       Louis I. Kane
# 335         BALDOR ELECTRIC CO     1981  1992    5686   R. S. Boreham Jr.
# 2542      NORTEL NETWORKS CORP     7980  1992    1648   Paul George Stern
# 1698             HONEYWELL INC     5693  1992    1162     James J. Renier
# 1296              FEDDERS CORP     4595  1987    8921  Salvatore Giordano
#
#       depart_code  ceo_dismi interim_or_co  tenure_no  max_tenure  fy_gone
# id
# 1996          5.0        0.0           NaN          1           1   2019.0  \
# 8193          2.0        0.0           NaN          1           1   2019.0
# 9029          NaN        NaN           NaN          1           1      NaN
# 6119          NaN        NaN           NaN          1           1      NaN
# 6069          NaN        NaN           NaN          1           1      NaN
# ...           ...        ...           ...        ...         ...      ...
# 5458          5.0        0.0           NaN          1           1   1994.0
# 335           5.0        0.0           NaN          1           2   1993.0
# 2542          3.0        1.0           NaN          1           1   1993.0
# 1698          3.0        1.0           NaN          1           1   1993.0
# 1296          5.0        0.0           NaN          1           2   1988.0
#
#                 date_gone still_active
# id
# 1996  2019-09-30 00:00:00          NaN  \
# 8193  2019-01-10 00:00:00          NaN
# 9029                  NaN    03feb2021
# 6119                  NaN     probably
# 6069                  NaN     probably
# ...                   ...          ...
# 5458  1994-05-25 00:00:00          NaN
# 335   1993-01-03 00:00:00          NaN
# 2542  1993-02-28 00:00:00          NaN
# 1698  1993-04-20 00:00:00          NaN
# 1296  1988-01-01 00:00:00          NaN
#
#                                                  notes1
# id
# 1996  Executive gave one month notice although the c...  \
# 8193  Accenture PLC announced in a January 11th, 201...
# 9029                                                NaN
# 6119                                                NaN
# 6069                                                NaN
# ...                                                 ...
# 5458  LOUIS I. KANE, Director since 1981, co-founder...
# 335   Roland S. Boreham, Jr., was Baldor’s CEO from ...
# 2542  With profits and the share price dropping, Pau...
# 1698  Renier resigned as chairman and CEO in 1993, s...
# 1296  Salvatore Giordano passed away 02/22/2003. Thi...
#
#                                                  notes2
# id
# 1996  https://exechange.com/13794/kelly-services-ceo...
# 8193  https://newsroom.accenture.com/news/accenture-...
# 9029  https://craft.co/arcosa/executives#:~:text=Arc...
# 6119                                                NaN
# 6069                                                NaN
# ...                                                 ...
# 5458  https://sec.report/Document/0001029869-98-0007...
# 335   http://www.annualreports.com/HostedData/Annual...
# 2542  https://www.theglobeandmail.com/report-on-busi...
# 1698  http://www.fundinguniverse.com/company-histori...
# 1296  https://www.newjerseyhills.com/salvatore-giord...
#
# [9390 rows x 15 columns]

# %% [markdown]
# 10. Sortiere den Datensatz nun wieder nach dem ursprünglichen Index unter Verwendung des `inplace` Arguments.

# %%
df.sort_index(inplace=True)
df
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 1                         AAR CORP     1004  1995    5622  \
# 2                         AAR CORP     1004  2017    5623
# 3                         AAR CORP     1004  2018   51547
# 4       ADC TELECOMMUNICATIONS INC     1013  2000    2611
# 5       ADC TELECOMMUNICATIONS INC     1013  2003   23275
# ...                            ...      ...   ...     ...
# 55863        BED BATH & BEYOND INC    25338  1993   10653
# 556717           RENT-A-CENTER INC    31460  2017   36115
# 556718           RENT-A-CENTER INC    31460  2019   36117
# 557049           TRAVELERS COS INC    62689  1999   12200
# 559029         DESIGNER BRANDS INC    24171  2008   54815
#
#                         ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 1                 Ira A. Eichner          5.0        0.0           NaN  \
# 2                David P. Storch          5.0        0.0           NaN
# 3       John McClain Holmes, III          NaN        NaN           NaN
# 4             William J. Cadogan          6.0        0.0           NaN
# 5             Richard R. Roscitt          6.0        0.0           NaN
# ...                          ...          ...        ...           ...
# 55863           Warren Eisenberg          9.0        NaN        CO-CEO
# 556717            Mark E. Speese          3.0        1.0           NaN
# 556718         Mitchell E. Fadel          NaN        NaN           NaN
# 557049            Jay S. Fishman          7.0        0.0           NaN
# 559029      Jay L. Schottenstein          5.0        0.0           NaN
#
#         tenure_no  max_tenure  fy_gone            date_gone still_active
# id
# 1               1           1   1996.0  1996-10-01 00:00:00          NaN  \
# 2               1           1   2018.0  2018-05-31 00:00:00          NaN
# 3               1           1      NaN                  NaN    17nov2020
# 4               1           1   2001.0  2001-02-15 00:00:00          NaN
# 5               1           1   2003.0  2003-08-13 00:00:00          NaN
# ...           ...         ...      ...                  ...          ...
# 55863           1           2      NaN                  NaN          NaN
# 556717          2           2   2018.0  2018-01-01 00:00:00          NaN
# 556718          1           1      NaN                  NaN    03feb2021
# 557049          1           2   2001.0  2001-01-01 00:00:00          NaN
# 559029          1           1   2009.0  2009-04-27 00:00:00          NaN
#
#                                                    notes1
# id
# 1       Mr. Ira A. Eichner served as CEO until October...  \
# 2       Agreed to stay as non-executive chairman post ...
# 3                                                     NaN
# 4       William Cadogan, the retiring CEO and chairman...
# 5       Richard R. "Rick" Roscitt has accepted a new p...
# ...                                                   ...
# 55863   He didn't leave but wasn't shown as CEO by exe...
# 556717  He started this stint as interim but stayed on...
# 556718                                                NaN
# 557049  ay Steven Fishman (November 4, 1952 – August 1...
# 559029  there was some family fighting around the time...
#
#                                                    notes2
# id
# 1       https://www.comparably.com/companies/aar-corp/...
# 2       https://advance-lexis-com.umiss.idm.oclc.org/a...
# 3       https://www.aarcorp.com/about/corporate-officers/
# 4       https://www.bizjournals.com/twincities/stories...
# 5       https://www.businesswire.com/news/home/2003081...
# ...                                                   ...
# 55863                                                 NaN
# 556717  https://www.businesswire.com/news/home/2017041...
# 556718                                                NaN
# 557049       https://en.wikipedia.org/wiki/Jay_S._Fishman
# 559029  https://www.sec.gov/Archives/edgar/data/131994...
#
# [9390 rows x 15 columns]

# %% [markdown]
# 11. Ziehe eine zufällige Stichprobe (mit Zurücklegen), deren Größe 40% des originalen Datensatzes entspricht. Verwende dafür die *Seed* 2023 (d.h. setze `random_state=2023`).

# %%
df.sample(frac=0.4, replace=True, random_state=2023)
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 4845             EOG RESOURCES INC    16478  1998    9312  \
# 5504     AMBAC FINANCIAL GROUP INC    24287  2003   10807
# 2688         PACIFIC TELESIS GROUP     8286  1996    1739
# 5883     ULTRAMAR DIAMOND SHAMROCK    25422  1996   10992
# 5695          SBS TECHNOLOGIES INC    24832  2002   23031
# ...                            ...      ...   ...     ...
# 4884        DIGI INTERNATIONAL INC    16710  2014   20851
# 8073       JANUS CAPITAL GROUP INC   137232  2002   21695
# 511   RESOLUTE FOREST PRODUCTS INC     2337  2019   45071
# 137                 US ECOLOGY INC     1439  2019   49520
# 640               CAMPBELL SOUP CO     2663  2019   62316
#
#                  ceo_name  depart_code  ceo_dismi interim_or_co  tenure_no
# id
# 4845   Forrest E. Hoglund          5.0        0.0           NaN          1  \
# 5504  Phillip B. Lassiter          5.0        0.0           NaN          1
# 2688    Philip J. Quigley          7.0        0.0           NaN          1
# 5883          Jean Gaulin          7.0        0.0           NaN          1
# 5695     Grahame E. Rance          5.0        0.0           NaN          1
# ...                   ...          ...        ...           ...        ...
# 4884   Joseph T. Dunsmore          5.0        0.0           NaN          1
# 8073  Landon Hill Rowland          7.0        0.0           NaN          1
# 511         Yves Laflamme          NaN        NaN           NaN          1
# 137     Jeffrey R. Feeler          NaN        NaN           NaN          1
# 640        Mark A. Clouse          NaN        NaN           NaN          1
#
#       max_tenure  fy_gone            date_gone still_active
# id
# 4845           1   1998.0  1998-09-09 00:00:00          NaN  \
# 5504           1   2004.0  2004-01-27 00:00:00          NaN
# 2688           1   1997.0  1997-10-24 00:00:00    29dec2020
# 5883           2   1996.0  1996-12-02 00:00:00          NaN
# 5695           1   2002.0  2002-04-26 00:00:00          NaN
# ...          ...      ...                  ...          ...
# 4884           1   2015.0  2014-12-17 00:00:00          NaN
# 8073           1      NaN                  NaN          NaN
# 511            1      NaN                  NaN     probably
# 137            1      NaN                  NaN    23oct2020
# 640            1      NaN                  NaN     probably
#
#                                                  notes1
# id
# 4845  Forrest E. Hoglund, EOG Chairman, who announce...  \
# 5504  Mr. Lassiter retired as C.E.O. of A.M.B.A.C. F...
# 2688  Pacific Telesis Group chief executive Philip J...
# 5883  Jean R. Gaulin has served as Chairman of the B...
# 5695  Former Chairman and Chief Executive Officer, G...
# ...                                                 ...
# 4884  MINNEAPOLIS, April 23, 2014 - Digi Internation...
# 8073  Rowland, who was CEO of both Stillwell spinoff...
# 511                                                 NaN
# 137                                                 NaN
# 640                                                 NaN
#
#                                                  notes2
# id
# 4845  http://www.gasandoil.com/news/n_america/298a2d...
# 5504  http://ir.ambac.com/node/9431/html#toc50308_36...
# 2688  https://www.bizjournals.com/sanfrancisco/stori...
# 5883  https://www.sec.gov/Archives/edgar/data/887207...
# 5695  http://media.corporate-ir.net/media_files/irol...
# ...                                                 ...
# 4884  https://www.digi.com/news/press-releases/913\n...
# 8073  (Wall Street Journal 1) By, A. L. (2002, Oct 3...
# 511                                                 NaN
# 137   https://investors.usecology.com/corporate-gove...
# 640                                                 NaN
#
# [3756 rows x 15 columns]

# %% [markdown]
# 12. Selektiere alle CEOs, die eine 3. oder sogar 4. Amtszeit (`tenure_no`) angetreten haben (=potenzielle Ausreißer?).

# %%
df[df['tenure_no'] >= 3]  # oder: df[df['tenure_no'] in [3, 4]]
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 209                  ANALOGIC CORP     1633  2007   15471  \
# 1415                 FORD MOTOR CO     4839  2017   23940
# 2854         POWELL INDUSTRIES INC     8699  2016   39127
# 3278  STEWART INFORMATION SERVICES    10086  2010   22977
# 4305                PHOTRONICS INC    13200  2005   10503
# 4307                PHOTRONICS INC    13200  2015   10503
# 4790                 TREDEGAR CORP    15459  2018    7619
# 5816                     AGCO CORP    25180  2003    8383
# 8032                CONVERSANT INC   133547  2012   32004
# 8086  CALIFORNIA PIZZA KITCHEN INC   138321  2007   31930
#
#                         ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 209        Bernard M. Gordon, MS          9.0        NaN           NaN  \
# 1415      William Clay Ford, Jr.          9.0        NaN           NaN
# 2854            Thomas W. Powell          7.0        0.0       Interim
# 3278           Malcolm S. Morris          5.0        0.0        CO-CEO
# 4305  Constantine S. Macricostas          7.0        0.0           NaN
# 4307  Constantine S. Macricostas          7.0        0.0           NaN
# 4790            John D. Gottwald          5.0        0.0           NaN
# 5816           Robert J. Ratliff          5.0        0.0           NaN
# 8032             James R. Zarley          5.0        0.0           NaN
# 8086               Larry S. Flax          5.0        0.0        CO-CEO
#
#       tenure_no  max_tenure  fy_gone            date_gone still_active
# id
# 209           3           3      NaN                  NaN          NaN  \
# 1415          3           3      NaN                  NaN          NaN
# 2854          3           3   2017.0  2016-10-01 00:00:00          NaN
# 3278          3           3   2011.0  2011-11-01 00:00:00          NaN
# 4305          3           4   2005.0  2005-06-01 00:00:00    12oct2020
# 4307          4           4   2015.0  2015-05-04 00:00:00    12oct2020
# 4790          3           3   2019.0  2019-03-19 00:00:00          NaN
# 5816          3           3   2004.0  2004-07-01 00:00:00          NaN
# 8032          3           3   2012.0  2012-12-05 00:00:00          NaN
# 8086          3           1   2011.0  2011-08-01 00:00:00          NaN
#
#                                                  notes1
# id
# 209             Execucomp shows him leaving - he didn't  \
# 1415                                                NaN
# 2854  On September 27, 2016, the board of directors ...
# 3278  He let go of the CEO role but stayed on as pre...
# 4305  Constantine S. Macricostas is Chairman of the ...
# 4307  Constantine S. Macricostas is Chairman of the ...
# 4790  Tredegar Corporation (NYSE:TG) today announced...
# 5816  July 31, 2006--AGCO Corporation (NYSE: AG), a ...
# 8032  EO James Zarley has resigned as CEO and has ta...
# 8086  Rick Rosenfield and Larry Flax, two former att...
#
#                                                  notes2
# id
# 209                                                 NaN
# 1415                                                NaN
# 2854  https://www.sec.gov/Archives/edgar/data/80420/...
# 3278  https://www.houstonchronicle.com/business/real...
# 4305  https://photronicsinc.gcs-web.com/directors/co...
# 4307  https://photronicsinc.gcs-web.com/directors/co...
# 4790  https://www.businesswire.com/news/home/2019022...
# 5816  https://investors.agcocorp.com/news-releases/n...
# 8032  https://www.conversantmedia.com/about-us/press...
# 8086  https://www.seafoodnews.com/Story/1044206/Two-...

# %% [markdown]
# 13. Selektiere alle CEOs, deren `ceo_name` mit einem `L` beginnt. (*Tipp: Wirf einen Blick in die [`pandas` Dokumentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.startswith.html)*)

# %%
df[df['ceo_name'].str.startswith('L')]
# Out:
#                           firm_name  firm_id  year  ceo_id
# id
# 20                     AEROFLEX INC     1056  2008   19963  \
# 33                       ACETO CORP     1094  2009   11077
# 48           ADVANCED MICRO DEVICES     1161  2019   46953
# 75                ALBERTO-CULVER CO     1239  1993      33
# 79                  ALBERTSON'S INC     1240  2005   23904
# ...                             ...      ...   ...     ...
# 8858          CLEARWATER PAPER CORP   181931  2017   37542
# 8889          FINANCIAL ENGINES INC   184009  2017   44692
# 8971       NATIONAL BANK HLDGS CORP   190963  2010   54017
# 9021                FUTUREFUEL CORP   287462  2013   48303
# 19415  TELEPHONE & DATA SYSTEMS INC    10411  1993    4008
#
#                        ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 20                Leonard Borow          NaN        NaN           NaN  \
# 33          Leonard S. Schwartz          5.0        0.0           NaN
# 48                   Lisa T. Su          NaN        NaN           NaN
# 75             Leonard H. Lavin          5.0        0.0           NaN
# 79         Lawrence R. Johnston          7.0        0.0           NaN
# ...                         ...          ...        ...           ...
# 8858           Linda K. Massman          NaN        NaN           NaN
# 8889   Lawrence Michael Raffone          7.0        0.0           NaN
# 8971   Lawrence Kingsbaker Fish          5.0        0.0           NaN
# 9021              Lee E. Mikles          5.0        0.0           NaN
# 19415      LeRoy T. Carlson Jr.          9.0        NaN           NaN
#
#        tenure_no  max_tenure  fy_gone            date_gone still_active
# id
# 20             1           1      NaN                  NaN    16nov2020  \
# 33             1           1   2010.0  2009-11-20 00:00:00          NaN
# 48             1           1      NaN                  NaN    16nov2020
# 75             1           1   1995.0  1994-10-01 00:00:00          NaN
# 79             1           1   2006.0  2006-06-02 00:00:00          NaN
# ...          ...         ...      ...                  ...          ...
# 8858           1           1      NaN                  NaN          Yes
# 8889           1           1   2018.0  2018-07-23 00:00:00          NaN
# 8971           1           1   2010.0  2010-01-01 00:00:00          NaN
# 9021           1           1   2013.0  2013-01-01 00:00:00          NaN
# 19415          1           2      NaN                  NaN          NaN
#
#                                                   notes1
# id
# 20                                                   NaN  \
# 33     The company said he retired effective Nov. 20 ...
# 48                                                   NaN
# 75     Leonard Lavin built Albert-Culver Co. from a f...
# 79     On June 2, 2006, Emerald Acquisition Sub, Inc....
# ...                                                  ...
# 8858                                                 NaN
# 8889   SUNNYVALE, Calif.--(BUSINESS WIRE)--Financial ...
# 8971   On November 21, 2014, Lawrence K. Fish, a dire...
# 9021   Lee E. Mikles has submitted his resignation, e...
# 19415  Execucomp appears to confuse him with his dad ...
#
#                                                   notes2
# id
# 20      https://www.bloomberg.com/profile/person/1445657
# 33     http://www.boston.com/business/articles/2009/1...
# 48     https://www.amd.com/en/corporate/leadership-li...
# 75     https://www.chicagotribune.com/news/obituaries...
# 79     https://www.sec.gov/Archives/edgar/data/95521/...
# ...                                                  ...
# 8858                                                 NaN
# 8889   https://www.investmentnews.com/financial-engin...
# 8971   https://www.sec.gov/Archives/edgar/data/147584...
# 9021   https://www.stltoday.com/business/local/novell...
# 19415                                                NaN
#
# [331 rows x 15 columns]

# %% [markdown]
# ##### 3.5 Operationen auf Spalten
#
# *Hinweis: Durch klick auf das kleine `+` in der oberen Toolbar oder durch selektieren einer Code Zelle und klicken der Tasten `a` (above) oder `b` (below) können neue Code Zellen eingefügt werden.*

# %% [markdown]
# 1. Selektiere die ersten 3 Spalten und letzten 100 Zeilen des Datensatzes.

# %%
df.iloc[-100:, :3]
# Out:
#                          firm_name  firm_id  year
# id
# 8946    RENEWABLE ENERGY GROUP INC   187692  2017
# 8947    RENEWABLE ENERGY GROUP INC   187692  2018
# 8948    RENEWABLE ENERGY GROUP INC   187692  2019
# 8948                PROTO LABS INC   187696  2013
# 8949                PROTO LABS INC   187696  2017
# ...                            ...      ...   ...
# 55863        BED BATH & BEYOND INC    25338  1993
# 556717           RENT-A-CENTER INC    31460  2017
# 556718           RENT-A-CENTER INC    31460  2019
# 557049           TRAVELERS COS INC    62689  1999
# 559029         DESIGNER BRANDS INC    24171  2008
#
# [100 rows x 3 columns]

# %% [markdown]
# 2. Selektiere den Firmennamen, den CEO-Namen und die Information, ob diese/r immer noch im Amt ist. (*Achtung: Variablen aus dem Data Dictionary wurden umbenannt beim Datenimport!*)

# %%
df[['firm_name', 'ceo_name', 'still_active']]
# Out:
#                          firm_name                  ceo_name still_active
# id
# 1                         AAR CORP            Ira A. Eichner          NaN
# 2                         AAR CORP           David P. Storch          NaN
# 3                         AAR CORP  John McClain Holmes, III    17nov2020
# 4       ADC TELECOMMUNICATIONS INC        William J. Cadogan          NaN
# 5       ADC TELECOMMUNICATIONS INC        Richard R. Roscitt          NaN
# ...                            ...                       ...          ...
# 55863        BED BATH & BEYOND INC          Warren Eisenberg          NaN
# 556717           RENT-A-CENTER INC            Mark E. Speese          NaN
# 556718           RENT-A-CENTER INC         Mitchell E. Fadel    03feb2021
# 557049           TRAVELERS COS INC            Jay S. Fishman          NaN
# 559029         DESIGNER BRANDS INC      Jay L. Schottenstein          NaN
#
# [9390 rows x 3 columns]

# %% [markdown]
# 3. Selektiere alle Spalten außer die Spalten `max_tenure` und `date_gone` (d.h. diese sollen entfernt werden).

# %%
df.drop(['max_tenure', 'date_gone'], axis=1, inplace=False)
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 1                         AAR CORP     1004  1995    5622  \
# 2                         AAR CORP     1004  2017    5623
# 3                         AAR CORP     1004  2018   51547
# 4       ADC TELECOMMUNICATIONS INC     1013  2000    2611
# 5       ADC TELECOMMUNICATIONS INC     1013  2003   23275
# ...                            ...      ...   ...     ...
# 55863        BED BATH & BEYOND INC    25338  1993   10653
# 556717           RENT-A-CENTER INC    31460  2017   36115
# 556718           RENT-A-CENTER INC    31460  2019   36117
# 557049           TRAVELERS COS INC    62689  1999   12200
# 559029         DESIGNER BRANDS INC    24171  2008   54815
#
#                         ceo_name  depart_code  ceo_dismi interim_or_co
# id
# 1                 Ira A. Eichner          5.0        0.0           NaN  \
# 2                David P. Storch          5.0        0.0           NaN
# 3       John McClain Holmes, III          NaN        NaN           NaN
# 4             William J. Cadogan          6.0        0.0           NaN
# 5             Richard R. Roscitt          6.0        0.0           NaN
# ...                          ...          ...        ...           ...
# 55863           Warren Eisenberg          9.0        NaN        CO-CEO
# 556717            Mark E. Speese          3.0        1.0           NaN
# 556718         Mitchell E. Fadel          NaN        NaN           NaN
# 557049            Jay S. Fishman          7.0        0.0           NaN
# 559029      Jay L. Schottenstein          5.0        0.0           NaN
#
#         tenure_no  fy_gone still_active
# id
# 1               1   1996.0          NaN  \
# 2               1   2018.0          NaN
# 3               1      NaN    17nov2020
# 4               1   2001.0          NaN
# 5               1   2003.0          NaN
# ...           ...      ...          ...
# 55863           1      NaN          NaN
# 556717          2   2018.0          NaN
# 556718          1      NaN    03feb2021
# 557049          1   2001.0          NaN
# 559029          1   2009.0          NaN
#
#                                                    notes1
# id
# 1       Mr. Ira A. Eichner served as CEO until October...  \
# 2       Agreed to stay as non-executive chairman post ...
# 3                                                     NaN
# 4       William Cadogan, the retiring CEO and chairman...
# 5       Richard R. "Rick" Roscitt has accepted a new p...
# ...                                                   ...
# 55863   He didn't leave but wasn't shown as CEO by exe...
# 556717  He started this stint as interim but stayed on...
# 556718                                                NaN
# 557049  ay Steven Fishman (November 4, 1952 – August 1...
# 559029  there was some family fighting around the time...
#
#                                                    notes2
# id
# 1       https://www.comparably.com/companies/aar-corp/...
# 2       https://advance-lexis-com.umiss.idm.oclc.org/a...
# 3       https://www.aarcorp.com/about/corporate-officers/
# 4       https://www.bizjournals.com/twincities/stories...
# 5       https://www.businesswire.com/news/home/2003081...
# ...                                                   ...
# 55863                                                 NaN
# 556717  https://www.businesswire.com/news/home/2017041...
# 556718                                                NaN
# 557049       https://en.wikipedia.org/wiki/Jay_S._Fishman
# 559029  https://www.sec.gov/Archives/edgar/data/131994...
#
# [9390 rows x 13 columns]

# %% [markdown]
# 4. Ersetze die Beobachtungen mit Index `1`, `10` und `100` in der Spalte `ceo_dismi` durch ein `None` (*missing value*).

# %%
df.loc[[1, 10, 100], 'ceo_dismi']
# Out:
# id
# 1      0.0
# 10     0.0
# 100    1.0
# Name: ceo_dismi, dtype: float64

# %%
df.loc[[1, 10, 100], 'ceo_dismi'] = None
df.loc[[1, 10, 100], 'ceo_dismi']
# Out:
# id
# 1     NaN
# 10    NaN
# 100   NaN
# Name: ceo_dismi, dtype: float64

# %% [markdown]
# 5. Füge für alle leeren Einträge in der Variable `ceo_dismi` den Code `3` ein. Verwende dafür zusätzlich das `inplace` Argument.

# %%
df['ceo_dismi']
# Out:
# id
# 1         NaN
# 2         0.0
# 3         NaN
# 4         0.0
# 5         0.0
#          ...
# 55863     NaN
# 556717    1.0
# 556718    NaN
# 557049    0.0
# 559029    0.0
# Name: ceo_dismi, Length: 9390, dtype: float64

# %%
df['ceo_dismi'].fillna(3, inplace=True)
df['ceo_dismi']
# Out:
# id
# 1         3.0
# 2         0.0
# 3         3.0
# 4         0.0
# 5         0.0
#          ...
# 55863     3.0
# 556717    1.0
# 556718    3.0
# 557049    0.0
# 559029    0.0
# Name: ceo_dismi, Length: 9390, dtype: float64

# %% [markdown]
# 6. Nun nehmen wir an, dass bei der Kodierung (d.h. der Erhebung der Gründe für ein Ausscheiden eines CEOs (`depart_code`)) ein Fehler gemacht wurde. Der/die Kodierer:in ist in der Zeile verrutscht und hat stets einen um 1 zu niedrigen Code eingetragen. Erhöhe `depart_code` nachträglich um 1, um den Fehler zu korrigieren, und ersetz dabei die alte Spalte.

# %%
df['ceo_dismi']
# Out:
# id
# 1         3.0
# 2         0.0
# 3         3.0
# 4         0.0
# 5         0.0
#          ...
# 55863     3.0
# 556717    1.0
# 556718    3.0
# 557049    0.0
# 559029    0.0
# Name: ceo_dismi, Length: 9390, dtype: float64

# %%
df['ceo_dismi'] = df['ceo_dismi'] + 1
df['ceo_dismi']
# Out:
# id
# 1         4.0
# 2         1.0
# 3         4.0
# 4         1.0
# 5         1.0
#          ...
# 55863     4.0
# 556717    2.0
# 556718    4.0
# 557049    1.0
# 559029    1.0
# Name: ceo_dismi, Length: 9390, dtype: float64

# %% [markdown]
# 7. Benenne die angepasste Spalte `depart_code` in `depart_code_new` um.

# %%
df.rename({'depart_code': 'depart_code_new'}, axis=1, inplace=True)
df
# Out:
#                          firm_name  firm_id  year  ceo_id
# id
# 1                         AAR CORP     1004  1995    5622  \
# 2                         AAR CORP     1004  2017    5623
# 3                         AAR CORP     1004  2018   51547
# 4       ADC TELECOMMUNICATIONS INC     1013  2000    2611
# 5       ADC TELECOMMUNICATIONS INC     1013  2003   23275
# ...                            ...      ...   ...     ...
# 55863        BED BATH & BEYOND INC    25338  1993   10653
# 556717           RENT-A-CENTER INC    31460  2017   36115
# 556718           RENT-A-CENTER INC    31460  2019   36117
# 557049           TRAVELERS COS INC    62689  1999   12200
# 559029         DESIGNER BRANDS INC    24171  2008   54815
#
#                         ceo_name  depart_code_new  ceo_dismi_new
# id
# 1                 Ira A. Eichner              5.0            4.0  \
# 2                David P. Storch              5.0            1.0
# 3       John McClain Holmes, III              NaN            4.0
# 4             William J. Cadogan              6.0            1.0
# 5             Richard R. Roscitt              6.0            1.0
# ...                          ...              ...            ...
# 55863           Warren Eisenberg              9.0            4.0
# 556717            Mark E. Speese              3.0            2.0
# 556718         Mitchell E. Fadel              NaN            4.0
# 557049            Jay S. Fishman              7.0            1.0
# 559029      Jay L. Schottenstein              5.0            1.0
#
#        interim_or_co  tenure_no  max_tenure  fy_gone            date_gone
# id
# 1                NaN          1           1   1996.0  1996-10-01 00:00:00  \
# 2                NaN          1           1   2018.0  2018-05-31 00:00:00
# 3                NaN          1           1      NaN                  NaN
# 4                NaN          1           1   2001.0  2001-02-15 00:00:00
# 5                NaN          1           1   2003.0  2003-08-13 00:00:00
# ...              ...        ...         ...      ...                  ...
# 55863         CO-CEO          1           2      NaN                  NaN
# 556717           NaN          2           2   2018.0  2018-01-01 00:00:00
# 556718           NaN          1           1      NaN                  NaN
# 557049           NaN          1           2   2001.0  2001-01-01 00:00:00
# 559029           NaN          1           1   2009.0  2009-04-27 00:00:00
#
#        still_active                                             notes1
# id
# 1               NaN  Mr. Ira A. Eichner served as CEO until October...  \
# 2               NaN  Agreed to stay as non-executive chairman post ...
# 3         17nov2020                                                NaN
# 4               NaN  William Cadogan, the retiring CEO and chairman...
# 5               NaN  Richard R. "Rick" Roscitt has accepted a new p...
# ...             ...                                                ...
# 55863           NaN  He didn't leave but wasn't shown as CEO by exe...
# 556717          NaN  He started this stint as interim but stayed on...
# 556718    03feb2021                                                NaN
# 557049          NaN  ay Steven Fishman (November 4, 1952 – August 1...
# 559029          NaN  there was some family fighting around the time...
#
#                                                    notes2
# id
# 1       https://www.comparably.com/companies/aar-corp/...
# 2       https://advance-lexis-com.umiss.idm.oclc.org/a...
# 3       https://www.aarcorp.com/about/corporate-officers/
# 4       https://www.bizjournals.com/twincities/stories...
# 5       https://www.businesswire.com/news/home/2003081...
# ...                                                   ...
# 55863                                                 NaN
# 556717  https://www.businesswire.com/news/home/2017041...
# 556718                                                NaN
# 557049       https://en.wikipedia.org/wiki/Jay_S._Fishman
# 559029  https://www.sec.gov/Archives/edgar/data/131994...
#
# [9390 rows x 15 columns]

# %% [markdown]
# 8. Erzeuge einen zweiten DataFrame der das Jahr (`year`), den CEO-Namen (`ceo_name`) und die Anzahl der Amtszeiten (`tenure_no`) enthält. Nenne diesen neuen DataFrame `df2`.

# %%
df2 = df.loc[:, ['year', 'ceo_name', 'tenure_no']]  # df2[['year', 'ceo_name', 'tenure_no']]
df2
# Out:
#         year                  ceo_name  tenure_no
# id
# 1       1995            Ira A. Eichner          1
# 2       2017           David P. Storch          1
# 3       2018  John McClain Holmes, III          1
# 4       2000        William J. Cadogan          1
# 5       2003        Richard R. Roscitt          1
# ...      ...                       ...        ...
# 55863   1993          Warren Eisenberg          1
# 556717  2017            Mark E. Speese          2
# 556718  2019         Mitchell E. Fadel          1
# 557049  1999            Jay S. Fishman          1
# 559029  2008      Jay L. Schottenstein          1
#
# [9390 rows x 3 columns]

# %% [markdown]
# ##### 3.6 Datenaggregation auf Spalten
#
# *Hinweis: Durch klick auf das kleine `+` in der oberen Toolbar oder durch selektieren einer Code Zelle und klicken der Tasten `a` (above) oder `b` (below) können neue Code Zellen eingefügt werden.*

# %% [markdown]
# 1. Ermittle die maximale und minimale Anzahl an Amtszeiten (`tenure_no`) sowie das durchschnittliche `year` aller Beobachtungen im Datensatz. Ermittle zudem das Median-`year`. Was fällt dir auf?

# %%
df['tenure_no'].min()
# Out:
# 1

# %%
df['tenure_no'].max()
# Out:
# 4

# %%
df['year'].mean(), df['year'].median()

# mean < median: Indikator für Linksschiefe (potenziell mehr niedrige Outlier)
# mean > median: Indikator für Rechtsschiefe (potenziell mehr hohe Outlier)
# Out:
# (2007.7616613418531, 2008.0)

# %% [markdown]
# 2. Ermittle die Korrelation zwischen `year` und `year_gone`. Warum beobachten wir eine Korrelation < 1?

# %%
# Vermutung: 'year' als Jahr der Verkündung, 'fy_gone' als Jahr der Umsetzung
df['year'].corr(df['fy_gone'])
# Out:
# 0.5253167615144724

# %% [markdown]
# 3. Was sind die top 5 Unternehmen mit den meisten Events (d.h. Beobachtungen) im Datensatz?

# %%
df['firm_name'].value_counts().head(n=5)
# Out:
# firm_name
# SEARS HOLDINGS CORP            11
# GREAT ELM CAPITAL GROUP INC    10
# BIOLASE INC                     9
# NTN BUZZTIME INC                9
# BARRICK GOLD CORP               9
# Name: count, dtype: int64

# %% [markdown]
# 4. Führe eine *Z-Standardisierung* der Variable `tenure_no` durch.

# %%
(df['tenure_no'] - df['tenure_no'].mean()) / df['tenure_no'].std()
# Out:
# id
# 1        -0.154943
# 2        -0.154943
# 3        -0.154943
# 4        -0.154943
# 5        -0.154943
#             ...
# 55863    -0.154943
# 556717    5.857084
# 556718   -0.154943
# 557049   -0.154943
# 559029   -0.154943
# Name: tenure_no, Length: 9390, dtype: float64

# %%
# noch schneller mit der `zscore` Funktion aus dem scipy Package
from scipy import stats
stats.zscore(df['tenure_no'])
# Out:
# id
# 1        -0.154951
# 2        -0.154951
# 3        -0.154951
# 4        -0.154951
# 5        -0.154951
#             ...
# 55863    -0.154951
# 556717    5.857396
# 556718   -0.154951
# 557049   -0.154951
# 559029   -0.154951
# Name: tenure_no, Length: 9390, dtype: float64

# %% [markdown]
# 5. Selektiere alle *einzigartigen* Firmen, für die Beobachtungen in den Jahren 2000 oder früher vorliegen (d.h. keine Duplikate).

# %%
df[df['year'] <= 2000]['firm_name'].unique()
# Out:
# array(['AAR CORP', 'ADC TELECOMMUNICATIONS INC', 'ALPHARMA INC -CL A',
#        ..., 'PALM INC', 'GRANT PRIDECO INC', 'VIASYS HEALTHCARE INC'],
#       dtype=object)

# %% [markdown]
# 6. Liste alle CEOs, die mindestens drei Mal ihr Amt niedergelegt haben.

# %%
ceo_counts = df['ceo_name'].value_counts()
ceo_counts[ceo_counts >= 3]
# Out:
# ceo_name
# Constantine S. Macricostas    4
# Amin J. Khoury                4
# John W. Rowe                  4
# Edward D. Breen               4
# Mel Karmazin                  4
# Mark Vincent Hurd             4
# William J. Miller             3
# Brian Charles Duperreault     3
# Harry C. Stonecipher          3
# Eric A. Benhamou              3
# Richard M. Beyer              3
# Richard C. Notebaert          3
# Richard M. Haddrill           3
# Daniel Francis Akerson        3
# David Allen Brandon           3
# Jay L. Schottenstein          3
# James R. Zarley               3
# William P. Stiritz            3
# Margaret Cushing Whitman      3
# Todd S. Nelson                3
# Michael D. Capellas           3
# Herbert J. Zarkin             3
# Sammy K. Duncan               3
# Fred Hassan                   3
# Dale W. Hilpert               3
# Norman C. Payson              3
# Robert B. Catell              3
# David C. Peterschmidt         3
# Walter M. Higgins III         3
# Joel N. Waller                3
# John D. Gottwald              3
# Thomas W. Powell              3
# Henry Brewer Schacht          3
# Laurence Alan Tisch           3
# Parker Steven Kennedy         3
# Russell P. Fradin             3
# Richard A. Smith              3
# Craig A. Rogerson             3
# Ronald Marshall               3
# Gregory Q. Brown              3
# Robert J. Ratliff             3
# Paul A. Perrault              3
# Mark S. Ordan                 3
# Murray S. Kessler             3
# Albert L. Lord                3
# Robert W. Decherd             3
# Robert J. DiNicola            3
# Philip M. Pead                3
# Jay S. Fishman                3
# Randall D. Stilley            3
# Robert H. Fish                3
# Lee A. Kennedy                3
# Malcolm S. Morris             3
# Jeffrey A. Graves             3
# Stephen J. Luczo              3
# Richard E. Belluzzo           3
# Ivan G. Seidenberg            3
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.7 Operationen auf Gruppen
#
# *Hinweis: Durch klick auf das kleine `+` in der oberen Toolbar oder durch selektieren einer Code Zelle und klicken der Tasten `a` (above) oder `b` (below) können neue Code Zellen eingefügt werden.*

# %% [markdown]
# 1. Gruppiere die Daten nach dem Jahr und zähle die Anzahl der Beobachtungen pro Jahr mittels `.size()`.

# %%
df.groupby('year').size()  # alternativ: df['year'].value_counts()
# Out:
# year
# 1987      1
# 1992     58
# 1993    185
# 1994    240
# 1995    221
# 1996    316
# 1997    325
# 1998    350
# 1999    396
# 2000    368
# 2001    231
# 2002    258
# 2003    264
# 2004    324
# 2005    277
# 2006    334
# 2007    365
# 2008    301
# 2009    248
# 2010    300
# 2011    296
# 2012    288
# 2013    261
# 2014    312
# 2015    324
# 2016    317
# 2017    963
# 2018    825
# 2019    440
# 2020      1
# 2109      1
# dtype: int64

# %% [markdown]
# 2. Gruppiere die Daten nach dem Jahr und berechne den `mean` sowie `median` für `max_tenure` pro Jahr.

# %%
df.groupby('year')['max_tenure'].agg(['mean', 'median'])
# Out:
#           mean  median
# year
# 1987  2.000000     2.0
# 1992  1.034483     1.0
# 1993  1.037838     1.0
# 1994  1.016667     1.0
# 1995  1.036199     1.0
# 1996  1.047468     1.0
# 1997  1.043077     1.0
# 1998  1.051429     1.0
# 1999  1.047980     1.0
# 2000  1.065217     1.0
# 2001  1.125541     1.0
# 2002  1.046512     1.0
# 2003  1.094697     1.0
# 2004  1.061728     1.0
# 2005  1.054152     1.0
# 2006  1.047904     1.0
# 2007  1.068493     1.0
# 2008  1.076412     1.0
# 2009  1.076613     1.0
# 2010  1.053333     1.0
# 2011  1.040541     1.0
# 2012  1.062500     1.0
# 2013  1.034483     1.0
# 2014  1.048077     1.0
# 2015  1.067901     1.0
# 2016  1.053628     1.0
# 2017  1.029076     1.0
# 2018  1.012121     1.0
# 2019  1.038636     1.0
# 2020  1.000000     1.0
# 2109  1.000000     1.0

# %% [markdown]
# 3. Gruppiere die Daten nach dem Jahr und berechne den `mean` sowie `median` für `max_tenure` pro Jahr. Nenne die neu entstehenden Spalten `Mittelwert` sowie `Median`.

# %%
df.groupby('year')['max_tenure'].agg([('Mittelwert', 'mean'), ('Median', 'median')])
# Out:
#       Mittelwert  Median
# year
# 1987    2.000000     2.0
# 1992    1.034483     1.0
# 1993    1.037838     1.0
# 1994    1.016667     1.0
# 1995    1.036199     1.0
# 1996    1.047468     1.0
# 1997    1.043077     1.0
# 1998    1.051429     1.0
# 1999    1.047980     1.0
# 2000    1.065217     1.0
# 2001    1.125541     1.0
# 2002    1.046512     1.0
# 2003    1.094697     1.0
# 2004    1.061728     1.0
# 2005    1.054152     1.0
# 2006    1.047904     1.0
# 2007    1.068493     1.0
# 2008    1.076412     1.0
# 2009    1.076613     1.0
# 2010    1.053333     1.0
# 2011    1.040541     1.0
# 2012    1.062500     1.0
# 2013    1.034483     1.0
# 2014    1.048077     1.0
# 2015    1.067901     1.0
# 2016    1.053628     1.0
# 2017    1.029076     1.0
# 2018    1.012121     1.0
# 2019    1.038636     1.0
# 2020    1.000000     1.0
# 2109    1.000000     1.0

# %% [markdown]
# 4. Gruppiere die Daten nach dem Jahr und filter für Jahre mit mehr als 250 Beobachtungen. *Hinweis: Die Größe eines `DataFrame`, d.h. die Anzahl der Beobachtungen, kann mittels `len(df)` ermittelt werden.*

# %%
df.groupby('year').apply(lambda g: len(g) > 250)
# Out:
# year
# 1987    False
# 1992    False
# 1993    False
# 1994    False
# 1995    False
# 1996     True
# 1997     True
# 1998     True
# 1999     True
# 2000     True
# 2001    False
# 2002     True
# 2003     True
# 2004     True
# 2005     True
# 2006     True
# 2007     True
# 2008     True
# 2009    False
# 2010     True
# 2011     True
# 2012     True
# 2013     True
# 2014     True
# 2015     True
# 2016     True
# 2017     True
# 2018     True
# 2019     True
# 2020    False
# 2109    False
# dtype: bool

# %% [markdown]
# 5. Gruppiere die Daten nach dem Jahr und zähle die Anzahl der Beobachtungen pro Jahr für CEOs in der zweiten Amtszeit.

# %%
df[df['tenure_no'] > 1].groupby('year').size()
# Out:
# year
# 1994     1
# 1995     1
# 1996     1
# 1997     2
# 1998     7
# 1999     8
# 2000    11
# 2001    11
# 2002     6
# 2003    13
# 2004     9
# 2005    10
# 2006     6
# 2007    11
# 2008    11
# 2009     9
# 2010     6
# 2011     8
# 2012    12
# 2013     4
# 2014     7
# 2015    14
# 2016    10
# 2017    26
# 2018     9
# 2019    18
# dtype: int64
